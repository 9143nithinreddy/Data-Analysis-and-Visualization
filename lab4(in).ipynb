# %%
import pandas as pd

# Define the dataset (assuming it's already loaded into a DataFrame)
data = {
    'outlook': ['sunny', 'sunny', 'overcast', 'rainy', 'rainy', 'rainy', 'overcast', 'sunny', 'sunny', 'rainy',
                'sunny', 'overcast', 'overcast', 'rainy'],
    'temperature': ['hot', 'hot', 'hot', 'mild', 'cool', 'cool', 'cool', 'mild', 'cool', 'mild', 'mild', 'mild', 'hot', 'mild'],
    'humidity': ['high', 'high', 'high', 'high', 'normal', 'normal', 'normal', 'high', 'normal', 'normal', 'normal', 'high', 'normal', 'high'],
    'windy': [False, True, False, False, False, True, True, False, False, False, True, True, False, True],
    'play': ['no', None, 'yes', 'yes', None, 'no', 'yes', 'no', 'yes', 'yes', None, 'yes', 'yes', 'no']
}

# Load into a DataFrame
df = pd.DataFrame(data)
print(df)
# df.shape
# Out:
#      outlook temperature humidity  windy  play
# 0      sunny         hot     high  False    no
# 1      sunny         hot     high   True  None
# 2   overcast         hot     high  False   yes
# 3      rainy        mild     high  False   yes
# 4      rainy        cool   normal  False  None
# 5      rainy        cool   normal   True    no
# 6   overcast        cool   normal   True   yes
# 7      sunny        mild     high  False    no
# 8      sunny        cool   normal  False   yes
# 9      rainy        mild   normal  False   yes
# 10     sunny        mild   normal   True  None
# 11  overcast        mild     high   True   yes
# 12  overcast         hot   normal  False   yes
# 13     rainy        mild     high   True    no

# %%
# Check for missing values
missing_values = df.isnull().sum()

# Display missing values
print("Missing Values:")
print(missing_values)
# Out:
# Missing Values:
# outlook        0
# temperature    0
# humidity       0
# windy          0
# play           3
# dtype: int64

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import missingno as msno

# Create DataFrame from dictionary
data = {
    'outlook': ['sunny', 'sunny', 'overcast', 'rainy', 'rainy', 'rainy', 'overcast', 'sunny', 'sunny', 'rainy',
                'sunny', 'overcast', 'overcast', 'rainy'],
    'temperature': ['hot', 'hot', 'hot', 'mild', 'cool', 'cool', 'cool', 'mild', 'cool', 'mild', 'mild', 'mild', 'hot', 'mild'],
    'humidity': ['high', 'high', 'high', 'high', 'normal', 'normal', 'normal', 'high', 'normal', 'normal', 'normal', 'high', 'normal', 'high'],
    'windy': [False, True, False, False, False, True, True, False, False, False, True, True, False, True],
    'play': ['no', None, 'yes', 'yes', None, 'no', 'yes', 'no', 'yes', 'yes', None, 'yes', 'yes', 'no']
}

df = pd.DataFrame(data)

# Visualize missing data
msno.matrix(df)
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create DataFrame from dictionary
data = {
    'outlook': ['sunny', 'sunny', 'overcast', 'rainy', 'rainy', 'rainy', 'overcast', 'sunny', 'sunny', 'rainy',
                'sunny', 'overcast', 'overcast', 'rainy'],
    'temperature': ['hot', 'hot', 'hot', 'mild', 'cool', 'cool', 'cool', 'mild', 'cool', 'mild', 'mild', 'mild', 'hot', 'mild'],
    'humidity': ['high', 'high', 'high', 'high', 'normal', 'normal', 'normal', 'high', 'normal', 'normal', 'normal', 'high', 'normal', 'high'],
    'windy': [False, True, False, False, False, True, True, False, False, False, True, True, False, True],
    'play': ['no', None, 'yes', 'yes', None, 'no', 'yes', 'no', 'yes', 'yes', None, 'yes', 'yes', 'no']
}

df = pd.DataFrame(data)

# Heatmap of missing data locations
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Data Locations")
plt.show()

# %%
df_cleaned = df.dropna()

# Display cleaned DataFrame
print("DataFrame after Dropping Rows with Any NaN Values:")
print(df_cleaned)
# Out:
# DataFrame after Dropping Rows with Any NaN Values:
#      outlook temperature humidity  windy play
# 0      sunny         hot     high  False   no
# 2   overcast         hot     high  False  yes
# 3      rainy        mild     high  False  yes
# 5      rainy        cool   normal   True   no
# 6   overcast        cool   normal   True  yes
# 7      sunny        mild     high  False   no
# 8      sunny        cool   normal  False  yes
# 9      rainy        mild   normal  False  yes
# 11  overcast        mild     high   True  yes
# 12  overcast         hot   normal  False  yes
# 13     rainy        mild     high   True   no

# %%
df_filled = df.fillna('no')

# Display the DataFrame after imputation
print("DataFrame after Imputing Missing Values with Constant:")
print(df_filled)
# Out:
# DataFrame after Imputing Missing Values with Constant:
#      outlook temperature humidity  windy play
# 0      sunny         hot     high  False   no
# 1      sunny         hot     high   True   no
# 2   overcast         hot     high  False  yes
# 3      rainy        mild     high  False  yes
# 4      rainy        cool   normal  False   no
# 5      rainy        cool   normal   True   no
# 6   overcast        cool   normal   True  yes
# 7      sunny        mild     high  False   no
# 8      sunny        cool   normal  False  yes
# 9      rainy        mild   normal  False  yes
# 10     sunny        mild   normal   True   no
# 11  overcast        mild     high   True  yes
# 12  overcast         hot   normal  False  yes
# 13     rainy        mild     high   True   no

# %%
df['play'] = df['play'].fillna(df['play'].mode()[0])

# Display the DataFrame after imputation
print("DataFrame after Imputing Missing Values with Mean:")
print(df)
# Out:
# DataFrame after Imputing Missing Values with Mean:
#      outlook temperature humidity  windy play
# 0      sunny         hot     high  False   no
# 1      sunny         hot     high   True  yes
# 2   overcast         hot     high  False  yes
# 3      rainy        mild     high  False  yes
# 4      rainy        cool   normal  False  yes
# 5      rainy        cool   normal   True   no
# 6   overcast        cool   normal   True  yes
# 7      sunny        mild     high  False   no
# 8      sunny        cool   normal  False  yes
# 9      rainy        mild   normal  False  yes
# 10     sunny        mild   normal   True  yes
# 11  overcast        mild     high   True  yes
# 12  overcast         hot   normal  False  yes
# 13     rainy        mild     high   True   no

# %%
df_filled = df.apply(lambda x: x.fillna(x.mode()[0]))

# Display the DataFrame after imputation
print("DataFrame after Imputing Missing Values with Mode:")
print(df_filled)
# Out:
# DataFrame after Imputing Missing Values with Mode:
#      outlook temperature humidity  windy play
# 0      sunny         hot     high  False   no
# 1      sunny         hot     high   True  yes
# 2   overcast         hot     high  False  yes
# 3      rainy        mild     high  False  yes
# 4      rainy        cool   normal  False  yes
# 5      rainy        cool   normal   True   no
# 6   overcast        cool   normal   True  yes
# 7      sunny        mild     high  False   no
# 8      sunny        cool   normal  False  yes
# 9      rainy        mild   normal  False  yes
# 10     sunny        mild   normal   True  yes
# 11  overcast        mild     high   True  yes
# 12  overcast         hot   normal  False  yes
# 13     rainy        mild     high   True   no
